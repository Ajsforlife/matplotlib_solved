# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis,bars_in_cities,color="b",align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations,cities)
# Out:
# ([<matplotlib.axis.XTick at 0x25ae8c87f08>,
#   <matplotlib.axis.XTick at 0x25ae8c94a88>,
#   <matplotlib.axis.XTick at 0x25ae8f4d408>,
#   <matplotlib.axis.XTick at 0x25ae8f56388>,
#   <matplotlib.axis.XTick at 0x25ae8f56c88>],
#  [Text(0, 0, 'New Orleans'),
#   Text(1, 0, 'Milwaukee'),
#   Text(2, 0, 'Omaha'),
#   Text(3, 0, 'Pittsburgh'),
#   Text(4, 0, 'Toledo')])

# %%
# Set the limits of the x axis
plt.xlim(-.75, len(bars_in_cities)-.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0,max(bars_in_cities)+.4)
# Out:
# (0.0, 9.0)

# %%
# Give the chart a title, x label, and y label
plt.xlabel("City")
plt.ylabel("Bars per 10,000 Households")
plt.title("Density of Bars per City")
# Out:
# Text(0.5, 1.0, 'Density of Bars per City')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("Images/Bar_Chart_Solved")
plt.show()
